# %% [markdown]
# # Testing Regression on Attractiveness Data

# %% [markdown]
# ## Firstly, Regression Without Gender Stratification

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Retrieve Data

# %%
train_txt = "data/regression_train_test/train_ratings.txt"
test_txt = "data/regression_train_test/test_ratings.txt"

with open(train_txt) as train_ratings:
    train_ratings = train_ratings.readlines()[0]
    train_ratings = np.array(train_ratings.split())
    train_ratings = train_ratings.astype(float)

with open(test_txt) as test_ratings:
    test_ratings = test_ratings.readlines()[0]
    test_ratings = np.array(test_ratings.split())
    test_ratings = test_ratings.astype(float)

print(train_ratings)
print(test_ratings)
# Out:
# [3.433333 2.9      3.966667 ... 3.05     2.4      2.666667]
# [2.333333 3.45     2.7      ... 2.533333 4.433333 3.05    ]

# %%
img_width = 224
img_height = 224

# %%
import PIL

def image_to_tensor(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    img = np.array(img)
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    return tensor

# %%
import pathlib

train_dir = pathlib.Path("data/regression_train_test/train")
test_dir = pathlib.Path("data/regression_train_test/test")

train_images = list(train_dir.glob("*.jpg"))
test_images = list(test_dir.glob("*.jpg"))

x_train = np.array([image_to_tensor(impath) for impath in train_images])
y_train = train_ratings

x_test = np.array([image_to_tensor(impath) for impath in test_images])
y_test = test_ratings

# %% [markdown]
# ### Make and Train Model

# %%
base_model = tf.keras.applications.ResNet152(input_shape=(img_width, img_height, 3), include_top=False, weights="imagenet")
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation="linear")
])

model.compile(optimizer="adam", loss="mean_squared_error", metrics=["MeanAbsoluteError"])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  global_average_pooling2d_2  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 58372993 (222.68 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=40, validation_data=(x_test, y_test))
# Out:
# Epoch 1/40
# 104/104 [==============================] - 595s 6s/step - loss: 0.5365 - mean_absolute_error: 0.5966 - val_loss: 0.4315 - val_mean_absolute_error: 0.5382
# Epoch 2/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.4493 - mean_absolute_error: 0.5497 - val_loss: 0.4320 - val_mean_absolute_error: 0.5236
# Epoch 3/40
# 104/104 [==============================] - 578s 6s/step - loss: 0.4453 - mean_absolute_error: 0.5455 - val_loss: 0.4155 - val_mean_absolute_error: 0.5135
# Epoch 4/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.4240 - mean_absolute_error: 0.5329 - val_loss: 0.3956 - val_mean_absolute_error: 0.5138
# Epoch 5/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.4140 - mean_absolute_error: 0.5246 - val_loss: 0.3975 - val_mean_absolute_error: 0.5236
# Epoch 6/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.4088 - mean_absolute_error: 0.5199 - val_loss: 0.3821 - val_mean_absolute_error: 0.5066
# Epoch 7/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3968 - mean_absolute_error: 0.5129 - val_loss: 0.3746 - val_mean_absolute_error: 0.4977
# Epoch 8/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3925 - mean_absolute_error: 0.5087 - val_loss: 0.3763 - val_mean_absolute_error: 0.4882
# Epoch 9/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3896 - mean_absolute_error: 0.5046 - val_loss: 0.3786 - val_mean_absolute_error: 0.5064
# Epoch 10/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3785 - mean_absolute_error: 0.4970 - val_loss: 0.3617 - val_mean_absolute_error: 0.4855
# Epoch 11/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3841 - mean_absolute_error: 0.5007 - val_loss: 0.3660 - val_mean_absolute_error: 0.4927
# Epoch 12/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3752 - mean_absolute_error: 0.4933 - val_loss: 0.3584 - val_mean_absolute_error: 0.4840
# Epoch 13/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3687 - mean_absolute_error: 0.4902 - val_loss: 0.3544 - val_mean_absolute_error: 0.4785
# Epoch 14/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3640 - mean_absolute_error: 0.4858 - val_loss: 0.3610 - val_mean_absolute_error: 0.4875
# Epoch 15/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3634 - mean_absolute_error: 0.4858 - val_loss: 0.3502 - val_mean_absolute_error: 0.4730
# Epoch 16/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3598 - mean_absolute_error: 0.4814 - val_loss: 0.3519 - val_mean_absolute_error: 0.4773
# Epoch 17/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3587 - mean_absolute_error: 0.4819 - val_loss: 0.3590 - val_mean_absolute_error: 0.4846
# Epoch 18/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3526 - mean_absolute_error: 0.4764 - val_loss: 0.3514 - val_mean_absolute_error: 0.4774
# Epoch 19/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3559 - mean_absolute_error: 0.4790 - val_loss: 0.3450 - val_mean_absolute_error: 0.4680
# Epoch 20/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3527 - mean_absolute_error: 0.4747 - val_loss: 0.3707 - val_mean_absolute_error: 0.4771
# Epoch 21/40
# 104/104 [==============================] - 579s 6s/step - loss: 0.3551 - mean_absolute_error: 0.4778 - val_loss: 0.3483 - val_mean_absolute_error: 0.4662
# Epoch 22/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3486 - mean_absolute_error: 0.4724 - val_loss: 0.3527 - val_mean_absolute_error: 0.4679
# Epoch 23/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3447 - mean_absolute_error: 0.4704 - val_loss: 0.3407 - val_mean_absolute_error: 0.4641
# Epoch 24/40
# 104/104 [==============================] - 578s 6s/step - loss: 0.3416 - mean_absolute_error: 0.4670 - val_loss: 0.3530 - val_mean_absolute_error: 0.4779
# Epoch 25/40
# 104/104 [==============================] - 578s 6s/step - loss: 0.3430 - mean_absolute_error: 0.4677 - val_loss: 0.3439 - val_mean_absolute_error: 0.4625
# Epoch 26/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3476 - mean_absolute_error: 0.4719 - val_loss: 0.3464 - val_mean_absolute_error: 0.4642
# Epoch 27/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3406 - mean_absolute_error: 0.4664 - val_loss: 0.3471 - val_mean_absolute_error: 0.4633
# Epoch 28/40
# 104/104 [==============================] - 580s 6s/step - loss: 0.3395 - mean_absolute_error: 0.4649 - val_loss: 0.3493 - val_mean_absolute_error: 0.4744
# Epoch 29/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3471 - mean_absolute_error: 0.4703 - val_loss: 0.3429 - val_mean_absolute_error: 0.4685
# Epoch 30/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3400 - mean_absolute_error: 0.4651 - val_loss: 0.3470 - val_mean_absolute_error: 0.4645
# Epoch 31/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3369 - mean_absolute_error: 0.4628 - val_loss: 0.3637 - val_mean_absolute_error: 0.4713
# Epoch 32/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3366 - mean_absolute_error: 0.4627 - val_loss: 0.3400 - val_mean_absolute_error: 0.4609
# Epoch 33/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3350 - mean_absolute_error: 0.4612 - val_loss: 0.3343 - val_mean_absolute_error: 0.4583
# Epoch 34/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3344 - mean_absolute_error: 0.4604 - val_loss: 0.3358 - val_mean_absolute_error: 0.4574
# Epoch 35/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3318 - mean_absolute_error: 0.4590 - val_loss: 0.3355 - val_mean_absolute_error: 0.4580
# Epoch 36/40
# 104/104 [==============================] - 577s 6s/step - loss: 0.3277 - mean_absolute_error: 0.4558 - val_loss: 0.3338 - val_mean_absolute_error: 0.4574
# Epoch 37/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3299 - mean_absolute_error: 0.4577 - val_loss: 0.3329 - val_mean_absolute_error: 0.4561
# Epoch 38/40
# 104/104 [==============================] - 576s 6s/step - loss: 0.3460 - mean_absolute_error: 0.4691 - val_loss: 0.3399 - val_mean_absolute_error: 0.4607
# Epoch 39/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3321 - mean_absolute_error: 0.4603 - val_loss: 0.3569 - val_mean_absolute_error: 0.4793
# Epoch 40/40
# 104/104 [==============================] - 575s 6s/step - loss: 0.3272 - mean_absolute_error: 0.4549 - val_loss: 0.3313 - val_mean_absolute_error: 0.4556

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
model.save("models/45_resnet_regression_1")
# Out:
# INFO:tensorflow:Assets written to: models/45_resnet_regression_1\assets
# INFO:tensorflow:Assets written to: models/45_resnet_regression_1\assets

# %% [markdown]
# ## Regression with Gender Stratification

# %%
def extract_ratings(text_path):
    with open(text_path) as ratings:
        ratings = ratings.readlines()
        ratings = np.array(ratings.split())
        ratings = ratings.astype(float)

    return ratings

# %%
m_train_txt = ""
